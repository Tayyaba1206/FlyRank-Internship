# %% [markdown]
# <a href="https://colab.research.google.com/github/Tayyaba1206/FlyRank-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Tayyaba1206/FlyRank-Internship"
REPO_DIR = "FlyRank-Internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/FlyRank-Internship

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'sample_data']

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tayyaba1206/FlyRank-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# Lane:
# Refresh / Content Opportunity Scoring
#
# ML Task Type:
# Scoring / Ranking
#
# This project ranks web pages based on their likelihood of requiring a content refresh. The goal is to prioritize which pages should be reviewed first using observed search performance signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is whether a page is declining in search performance.
#
# Proxy:
# trend_direction = "down"
#
# This proxy identifies pages that may require review or content updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Primary Metric:
# Precision@50
#
# A higher Precision@50 means that more of the top-ranked pages truly require attention.
#
# Business Action:
# Review and refresh the highest-ranked pages first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
print("Unit of Analysis: One row represents one content page.")

print("\nDataset Shape:", df.shape)

df[[
    "content_id",
    "content_type",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
# Unit of Analysis: One row represents one content page.
#
# Dataset Shape: (30000, 44)
#              content_id     content_type  impressions_90d   ctr  avg_position  \
# 0  content_304f48230142  keyword article             3803  0.76          10.6
# 1  content_a1fb4e703a9e  keyword article            15320  0.05          20.3
# 2  content_9aa793d4d895  keyword article            12581  0.09          36.5
# 3  content_331d6c4de07b  keyword article            11751  0.49           6.2
# 4  content_d99b7a2d90ca  keyword article            19140  0.13          44.0
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# The unit of analysis is a single content page.
#
# Each row in the dataset represents one web page with its search performance metrics, such as impressions, CTR, average position, and trend direction.
#
# The model will analyze each page individually and assign a score to help prioritize pages for content review or refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
