# %% [markdown]
# <a href="https://colab.research.google.com/github/Tayyaba1206/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/Tayyaba1206/FlyRank-Internship"
REPO_DIR = "FlyRank-Internship"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir(REPO_DIR)

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Working Directory:", os.getcwd())
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Working Directory: /FlyRank-Internship/FlyRank-Internship
# Rows: 30000
# Columns: 44

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tayyaba1206/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I selected the **Content Refresh and Optimization** lane.
# I chose this lane because web pages can lose search performance over time. By identifying pages that are likely to decline, content teams can prioritize updates for the most important pages. This project can help support better content decisions using data rather than guesswork.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Action:** The content or SEO team will review and update the highest-priority pages first.
#
# **Cost of a wrong recommendation:** If an important page is missed, search traffic may continue to decline. If low-priority pages are selected instead, time and effort may be wasted.
#
# **Why ML can help:** Machine learning can analyze multiple signals together and rank pages more effectively than a simple manual rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 4))

print("Average Search Volume:", round(df["search_volume"].mean(), 2))
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.5107
# Average Search Volume: 158.88

# %% [markdown]
# The starter dataset contains thousands of anonymized web pages. I will use a few summary statistics to understand the data and support why this lane is worth exploring.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This work is based on the provided anonymized dataset.
#
# The results are observational and directional. They are intended to support decision-making and should not be interpreted as proof of how Google's search algorithm works. The model can help prioritize pages for review but cannot guarantee future ranking changes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
